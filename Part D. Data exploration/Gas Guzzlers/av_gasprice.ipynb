# %%
import matplotlib.pyplot as plt

# Data
data = ["01/2016,56596270931.31685", "01/2017,22507570807.719795", "01/2018,52106060636.8451", "01/2019,13954460713.07759", "02/2016,69180681134.38847", "02/2017,23047230327.254307", "02/2018,23636574203.828968", "03/2016,32797039087.356663", "03/2017,23232253600.816833", "03/2018,15549765961.743269", "04/2016,23361180502.721275", "04/2017,22355124545.395313", "04/2018,13153739247.929977", "05/2016,23746277028.26325", "05/2017,23572314972.01526", "05/2018,17422505108.986427", "06/2016,23021251389.812138", "06/2017,30199442465.128723", "06/2018,16533308366.813042", "07/2016,22629542449.24175", "07/2017,25460300456.232983", "07/2018,27506077453.154324", "08/2015,159744029578.0331", "08/2016,22396836435.95848", "08/2017,25905774673.99024", "08/2018,18483235826.894573", "09/2015,56511301521.033226", "09/2016,25270403393.626083", "09/2017,30675032016.988663", "09/2018,15213870989.523375", "10/2015,53901692120.53661", "10/2016,32112869584.91468", "10/2017,17498286426.76892", "10/2018,14526936383.35001", "11/2015,53607614201.796776", "11/2016,24634294365.279957", "11/2017,15312465314.693556", "11/2018,16034859008.68164", "12/2015,55899526672.35486", "12/2016,50318068074.686455", "12/2017,33439362876.10833", "12/2018,16338844844.01465"]

# Convert data into two lists
dates = []
prices = []
for item in data:
    date, price = item.split(',')
    dates.append(date)
    prices.append(float(price))

# Create a line plot
fig, ax = plt.subplots(figsize=(12,6))
ax.plot(dates, prices,'-o', color='red')

# Add labels and title
ax.set_xlabel('Date')
ax.set_ylabel('Gas Price')
ax.set_title('Average Gas Price Over Time')

# Rotate x-axis labels for better readability
ax.tick_params(axis='x', rotation=45)
ax.grid(True)

# Display the plot
plt.show()
